# %% [markdown]
# ## [예제] 미국 대통령 당선 정보에서 정당 정보를 도출하여 시각하 하기
#
#
# ### * 불러온 데이타집합의 정보 확인하기
#
# - type(df)  : 데이타 타입
# - df.shape  : 행과 열의 수
# - df.columns : 컬럼명 확인
# - df.dtypes : 각각의 컬럼 데이타타입
# - df.info() : df.dtypes 비슷
# - df.info
# - df.head()
# - df.tail()
#
#
# ### 파이썬과 판다스 자료형 비교
#     int         int64
#     float       float64
#     string      object(****)
#
# ###  당선된 각 정당(Political Party) 수를 먼저 구해야 한다
#
# - value_counts() 이용
#
# - 원그래프 출력
#
#
# ### [연습] 데이타셋에서 다른 인사이드를 도출하여 시각화하기

# %%
import pandas as pd

# %%
df = pd.read_excel('http://qrc.depaul.edu/excel_files/presidents.xlsx')
df
# Out:
#                  President  Years in office  Year first inaugurated  \
# 0        George Washington              8.0                    1789
# 1               John Adams              4.0                    1797
# 2         Thomas Jefferson              8.0                    1801
# 3            James Madison              8.0                    1809
# 4             James Monroe              8.0                    1817
# 5        John Quincy Adams              4.0                    1825
# 6           Andrew Jackson              8.0                    1829
# 7        Martin Van Buren               4.0                    1837
# 8   William Henry Harrison              0.8                    1841
# 9            James K. Polk              4.0                    1845
# 10          Zachary Taylor              1.0                    1849
# 11         Franklin Pierce              4.0                    1853
# 12          James Buchanan              4.0                    1857
# 13         Abraham Lincoln              4.0                    1861
# 14        Ulysses S. Grant              8.0                    1869
# 15     Rutherford B. Hayes              4.0                    1877
# 16       James A. Garfield              0.5                    1881
# 17        Grover Cleveland              4.0                    1885
# 18       Benjamin Harrison              4.0                    1889
# 19        Grover Cleveland              4.0                    1893
# 20        William McKinley              4.0                    1897
# 21     William Howard Taft              4.0                    1909
# 22          Woodrow Wilson              8.0                    1913
# 23       Warren G. Harding              2.0                    1921
# 24          Herbert Hoover              4.0                    1929
# 25      Franklin Roosevelt             12.0                    1933
# 26    Dwight D. Eisenhower              8.0                    1953
# 27         John F. Kennedy              3.0                    1961
# 28        Richard M. Nixon              5.0                    1969
# 29            Jimmy Carter              4.0                    1977
# 30           Ronald Reagan              8.0                    1981
# 31             George Bush              4.0                    1989
# 32            Bill Clinton              8.0                    1993
# 33          George W. Bush              8.0                    2001
# 34            Barack Obama              NaN                    2009
#
#     Age at inauguration State elected from  # of electoral votes  \
# 0                    57           Virginia                    69
# 1                    61      Massachusetts                   132
# 2                    57           Virginia                    73
# 3                    57           Virginia                   122
# 4                    58           Virginia                   183
# 5                    57      Massachusetts                    84
# 6                    61          Tennessee                   178
# 7                    54           New York                   170
# 8                    68               Ohio                   234
# 9                    49          Tennessee                   170
# 10                   64          Louisiana                   163
# 11                   48      New Hampshire                   254
# 12                   65       Pennsylvania                   174
# 13                   52           Illinois                   180
# 14                   46           Illinois                   214
# 15                   54               Ohio                   185
# 16                   49               Ohio                   214
# 17                   47           New York                   219
# 18                   55            Indiana                   233
# 19                   55           New York                   277
# 20                   54               Ohio                   271
# 21                   51               Ohio                   321
# 22                   56         New Jersey                   435
# 23                   55               Ohio                   404
# 24                   54         California                   444
# 25                   51           New York                   472
# 26                   62           New York                   442
# 27                   43      Massachusetts                   303
# 28                   56           New York                   301
# 29                   52            Georgia                   297
# 30                   69         California                   489
# 31                   64              Texas                   426
# 32                   46           Arkansas                   370
# 33                   54              Texas                   271
# 34                   47           Illinois                   365
#
#    # of popular votes National total votes  Total electoral votes  \
# 0                NA()                 NA()                     69
# 1                NA()                 NA()                    139
# 2                NA()                 NA()                    137
# 3                NA()                 NA()                    176
# 4                NA()                 NA()                    221
# 5                NA()                 NA()                    261
# 6              642553              1148018                    261
# 7              764176              1503534                    294
# 8             1275390              2411808                    294
# 9             1339494              2703659                    275
# 10            1361393              2879184                    290
# 11            1607510              3161830                    296
# 12            1836072              4054647                    296
# 13            1865908              4685561                    303
# 14            3013650              5722440                    294
# 15            4034311              8413101                    369
# 16            4446158              9210420                    369
# 17            4874621             10049754                    401
# 18            5443892             11383320                    401
# 19            5551883             12056097                    444
# 20            7108480             13935738                    447
# 21            7676258             14882734                    483
# 22            6293152             15040963                    531
# 23           16133314             26753786                    531
# 24           21411991             36790364                    531
# 25           22825016             39749382                    531
# 26           33936137             61551118                    531
# 27           34221344             68828960                    537
# 28           31785148             73203370                    538
# 29           40830763             81555889                    538
# 30           43904153             86515221                    538
# 31           48886097             91584820                    538
# 32           44909326            104425014                    538
# 33           50460110            105417258                    538
# 34           69492376            129438754                    538
#
#     Rating points        Political Party       Occupation  \
# 0           842.0                   None          Planter
# 1           598.0             Federalist           Lawyer
# 2           711.0  Democratic-Republican  Planter, Lawyer
# 3           567.0  Democratic-Republican           Lawyer
# 4           602.0  Democratic-Republican           Lawyer
# 5           564.0  Democratic-Republican           Lawyer
# 6           632.0               Democrat           Lawyer
# 7           429.0               Democrat           Lawyer
# 8           329.0                   Whig          Soldier
# 9           632.0               Democrat           Lawyer
# 10          447.0                   Whig          Soldier
# 11          286.0               Democrat           Lawyer
# 12          259.0               Democrat           Lawyer
# 13          900.0             Republican           Lawyer
# 14          403.0             Republican          Soldier
# 15          477.0             Republican           Lawyer
# 16          444.0             Republican           Lawyer
# 17          576.0               Democrat           Lawyer
# 18          426.0             Republican           Lawyer
# 19          576.0               Democrat           Lawyer
# 20          601.0             Republican           Lawyer
# 21          491.0             Republican           Lawyer
# 22          723.0               Democrat         Educator
# 23          326.0             Republican           Editor
# 24          400.0             Republican         Engineer
# 25          876.0               Democrat           Lawyer
# 26          699.0             Republican          Soldier
# 27          704.0               Democrat           Author
# 28          477.0             Republican           Lawyer
# 29          518.0               Democrat      Businessman
# 30          634.0             Republican            Actor
# 31          548.0             Republican      Businessman
# 32          539.0               Democrat           Lawyer
# 33            NaN             Republican      Businessman
# 34            NaN               Democrat           Lawyer
#
#                  College  % electoral  % popular
# 0                   None   100.000000       NA()
# 1                Harvard    94.964029       NA()
# 2       William and Mary    53.284672       NA()
# 3              Princeton    69.318182       NA()
# 4       William and Mary    82.805430       NA()
# 5                Harvard    32.183908       NA()
# 6                   None    68.199234  55.970638
# 7                   None    57.823129  50.825322
# 8         Hampden-Sydney    79.591837  52.881075
# 9   U. of North Carolina    61.818182  49.543748
# 10                  None    56.206897  47.283987
# 11               Bowdoin    85.810811  50.841127
# 12             Dickinson    58.783784  45.283153
# 13                  None    59.405941   39.82251
# 14   US Military Academy    72.789116  52.663724
# 15                Kenyon    50.135501  47.952723
# 16              Williams    57.994580   48.27313
# 17                  None    54.613466  48.504879
# 18                 Miami    58.104738  47.823412
# 19                  None    62.387387  46.050417
# 20     Allegheny College    60.626398  51.008996
# 21                  Yale    66.459627  51.578279
# 22             Princeton    81.920904  41.840087
# 23                  None    76.082863  60.302919
# 24              Stanford    83.615819  58.199998
# 25               Harvard    88.888889  57.422317
# 26   US Military Academy    83.239171  55.134883
# 27               Harvard    56.424581  49.719397
# 28              Whittier    55.947955  43.420334
# 29      US Naval Academy    55.204461  50.064764
# 30        Eureka College    90.892193  50.747316
# 31                  Yale    79.182156  53.377947
# 32            Georgetown    68.773234  43.006292
# 33                  Yale    50.371747   47.86703
# 34   Columbia University    67.843866  53.687457

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   President               35 non-null     object
#  1   Years in office         34 non-null     float64
#  2   Year first inaugurated  35 non-null     int64
#  3   Age at inauguration     35 non-null     int64
#  4   State elected from      35 non-null     object
#  5   # of electoral votes    35 non-null     int64
#  6   # of popular votes      35 non-null     object
#  7   National total votes    35 non-null     object
#  8   Total electoral votes   35 non-null     int64
#  9   Rating points           33 non-null     float64
#  10  Political Party         35 non-null     object
#  11  Occupation              35 non-null     object
#  12  College                 35 non-null     object
#  13  % electoral             35 non-null     float64
#  14  % popular               35 non-null     object
# dtypes: float64(3), int64(4), object(8)
# memory usage: 4.2+ KB

# %%
df['Total electoral votes']
# Out:
# 0      69
# 1     139
# 2     137
# 3     176
# 4     221
# 5     261
# 6     261
# 7     294
# 8     294
# 9     275
# 10    290
# 11    296
# 12    296
# 13    303
# 14    294
# 15    369
# 16    369
# 17    401
# 18    401
# 19    444
# 20    447
# 21    483
# 22    531
# 23    531
# 24    531
# 25    531
# 26    531
# 27    537
# 28    538
# 29    538
# 30    538
# 31    538
# 32    538
# 33    538
# 34    538
# Name: Total electoral votes, dtype: int64

# %%
df['Political Party']
# Out:
# 0                      None
# 1                Federalist
# 2     Democratic-Republican
# 3     Democratic-Republican
# 4     Democratic-Republican
# 5     Democratic-Republican
# 6                  Democrat
# 7                  Democrat
# 8                      Whig
# 9                  Democrat
# 10                     Whig
# 11                 Democrat
# 12                 Democrat
# 13               Republican
# 14               Republican
# 15               Republican
# 16               Republican
# 17                 Democrat
# 18               Republican
# 19                 Democrat
# 20               Republican
# 21               Republican
# 22                 Democrat
# 23               Republican
# 24               Republican
# 25                 Democrat
# 26               Republican
# 27                 Democrat
# 28               Republican
# 29                 Democrat
# 30               Republican
# 31               Republican
# 32                 Democrat
# 33               Republican
# 34                 Democrat
# Name: Political Party, dtype: object

# %%
df['Political Party'].values_count
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12680\3280803808.py in <module>
# ----> 1 df['Political Party'].values(count)
#
# NameError: name 'count' is not defined

# %%
import
# Out:
#   File "C:\Users\kosmo\AppData\Local\Temp\ipykernel_12680\2437909390.py", line 1
#     df.Total electoral votes.plot()
#              ^
# SyntaxError: invalid syntax

# %%
df['Total electoral votes'].plot()
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as pit

# %%
pit.hist(df['Total electoral votes'])
# Out:
# (array([ 1.,  2.,  1.,  1., 10.,  0.,  2.,  3.,  2., 13.]),
#  array([ 69. , 115.9, 162.8, 209.7, 256.6, 303.5, 350.4, 397.3, 444.2,
#         491.1, 538. ]),
#  <BarContainer object of 10 artists>)

# %%
pit.pie(df['Total electoral votes'],labels=df['President'],startangle=90, autopct= '%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x26b7218a3a0>,
#   <matplotlib.patches.Wedge at 0x26b7218aac0>,
#   <matplotlib.patches.Wedge at 0x26b72198220>,
#   <matplotlib.patches.Wedge at 0x26b72198940>,
#   <matplotlib.patches.Wedge at 0x26b720250d0>,
#   <matplotlib.patches.Wedge at 0x26b720257f0>,
#   <matplotlib.patches.Wedge at 0x26b72025f10>,
#   <matplotlib.patches.Wedge at 0x26b72032670>,
#   <matplotlib.patches.Wedge at 0x26b72032d90>,
#   <matplotlib.patches.Wedge at 0x26b720404f0>,
#   <matplotlib.patches.Wedge at 0x26b7217e370>,
#   <matplotlib.patches.Wedge at 0x26b7204e340>,
#   <matplotlib.patches.Wedge at 0x26b7204ea60>,
#   <matplotlib.patches.Wedge at 0x26b7205b1c0>,
#   <matplotlib.patches.Wedge at 0x26b7205b8e0>,
#   <matplotlib.patches.Wedge at 0x26b7206a040>,
#   <matplotlib.patches.Wedge at 0x26b7206a760>,
#   <matplotlib.patches.Wedge at 0x26b7206ae80>,
#   <matplotlib.patches.Wedge at 0x26b720765e0>,
#   <matplotlib.patches.Wedge at 0x26b72076d00>,
#   <matplotlib.patches.Wedge at 0x26b72085460>,
#   <matplotlib.patches.Wedge at 0x26b72085b80>,
#   <matplotlib.patches.Wedge at 0x26b720942e0>,
#   <matplotlib.patches.Wedge at 0x26b72094a00>,
#   <matplotlib.patches.Wedge at 0x26b720a0160>,
#   <matplotlib.patches.Wedge at 0x26b720a0880>,
#   <matplotlib.patches.Wedge at 0x26b720a0fa0>,
#   <matplotlib.patches.Wedge at 0x26b720ac700>,
#   <matplotlib.patches.Wedge at 0x26b720ace20>,
#   <matplotlib.patches.Wedge at 0x26b720ba580>,
#   <matplotlib.patches.Wedge at 0x26b720baca0>,
#   <matplotlib.patches.Wedge at 0x26b720c6400>,
#   <matplotlib.patches.Wedge at 0x26b720c6b20>,
#   <matplotlib.patches.Wedge at 0x26b720d4280>,
#   <matplotlib.patches.Wedge at 0x26b720d49a0>],
#  [Text(-0.017690800679394575, 1.0998577342417164, 'George Washington'),
#   Text(-0.07097331621397446, 1.0977079704482386, 'John Adams'),
#   Text(-0.14139659254953027, 1.0908744215606956, 'Thomas Jefferson'),
#   Text(-0.22053711459737302, 1.0776657093389699, 'James Madison'),
#   Text(-0.3191751224784476, 1.0526762280924122, 'James Monroe'),
#   Text(-0.43518194325922493, 1.0102557479475802, 'John Quincy Adams'),
#   Text(-0.55458260013676, 0.9499674413502553, 'Andrew Jackson'),
#   Text(-0.6724987256856534, 0.8704857632099289, 'Martin Van Buren '),
#   Text(-0.7851254162748657, 0.770440186334552, 'William Henry Harrison'),
#   Text(-0.8801132130844571, 0.6598490222423258, 'James K. Polk'),
#   Text(-0.9591405112085795, 0.5385624195564942, 'Zachary Taylor'),
#   Text(-1.0235412633958945, 0.40294327407953623, 'Franklin Pierce'),
#   Text(-1.0692377008870033, 0.2583229354932994, 'James Buchanan'),
#   Text(-1.0947830026624803, 0.10700550023865076, 'Abraham Lincoln'),
#   Text(-1.0990426861641713, -0.045882175068790186, 'Ulysses S. Grant'),
#   Text(-1.0788825641960629, -0.21450504113826438, 'Rutherford B. Hayes'),
#   Text(-1.0262416081748322, -0.3960153553219044, 'James A. Garfield'),
#   Text(-0.9390610999658138, -0.5728562215172286, 'Grover Cleveland'),
#   Text(-0.8162343478729023, -0.7374018506570879, 'Benjamin Harrison'),
#   Text(-0.656150589433213, -0.8828739456946542, 'Grover Cleveland'),
#   Text(-0.46000755400204246, -0.9991962020849849, 'William McKinley'),
#   Text(-0.2343342488564731, -1.0747499522274344, 'William Howard Taft'),
#   Text(0.023843301645727476, -1.0997415591704403, 'Woodrow Wilson'),
#   Text(0.29257699948607735, -1.060376678059134, 'Warren G. Harding'),
#   Text(0.543473802400186, -0.9563661569214397, 'Herbert Hoover'),
#   Text(0.7612378398351057, -0.7940509751918841, 'Franklin Roosevelt'),
#   Text(0.9325931732814405, -0.5833266436130387, 'Dwight D. Eisenhower'),
#   Text(1.0475635000336558, -0.3355751978279041, 'John F. Kennedy'),
#   Text(1.0980574895904653, -0.06534332065548162, 'Richard M. Nixon'),
#   Text(1.0799196023514146, 0.209221539180752, 'Jimmy Carter'),
#   Text(0.9942065535159176, 0.4706945176502496, 'Ronald Reagan'),
#   Text(0.846281773022065, 0.7027141386443213, 'George Bush'),
#   Text(0.6454015433970249, 0.8907619478742558, 'Bill Clinton'),
#   Text(0.40413579479938144, 1.0230709942921226, 'George W. Bush'),
#   Text(0.13758155103875197, 1.0913621382537382, 'Barack Obama')],
#  [Text(-0.00964952764330613, 0.5999224004954816, '0.5%'),
#   Text(-0.038712717934895155, 0.5987498020626756, '1.0%'),
#   Text(-0.0771254141179256, 0.5950224117603794, '1.0%'),
#   Text(-0.12029297159856708, 0.5878176596394381, '1.3%'),
#   Text(-0.17409552135188047, 0.574187033504952, '1.6%'),
#   Text(-0.2373719690504863, 0.5510485897895891, '1.9%'),
#   Text(-0.3024996000745963, 0.5181640589183211, '1.9%'),
#   Text(-0.3668174867376291, 0.4748104162963248, '2.2%'),
#   Text(-0.42825022705901755, 0.42024010163702835, '2.2%'),
#   Text(-0.48006175259152195, 0.35991764849581404, '2.0%'),
#   Text(-0.523167551568316, 0.29376131975808767, '2.2%'),
#   Text(-0.5582952345795787, 0.21978724040701975, '2.2%'),
#   Text(-0.5832205641201836, 0.14090341935998146, '2.2%'),
#   Text(-0.5971543650886255, 0.05836663649380949, '2.2%'),
#   Text(-0.5994778288168207, -0.02502664094661283, '2.2%'),
#   Text(-0.5884813986523979, -0.11700274971178055, '2.7%'),
#   Text(-0.5597681499135448, -0.21600837563012965, '2.7%'),
#   Text(-0.5122151454358983, -0.3124670299184883, '3.0%'),
#   Text(-0.4452187352034012, -0.40221919126750244, '3.0%'),
#   Text(-0.3579003215090253, -0.48156760674253857, '3.3%'),
#   Text(-0.2509132112738413, -0.5450161102281735, '3.3%'),
#   Text(-0.12781868119443987, -0.5862272466695096, '3.6%'),
#   Text(0.013005437261305893, -0.5998590322747855, '3.9%'),
#   Text(0.1595874542651331, -0.5783872789413457, '3.9%'),
#   Text(0.29644025585464684, -0.5216542674116943, '3.9%'),
#   Text(0.41522063991005764, -0.43311871374102767, '3.9%'),
#   Text(0.5086871854262403, -0.3181781692434756, '3.9%'),
#   Text(0.5713982727456304, -0.1830410169970386, '4.0%'),
#   Text(0.5989404488675265, -0.035641811266626335, '4.0%'),
#   Text(0.5890470558280442, 0.11412083955313744, '4.0%'),
#   Text(0.542294483735955, 0.2567424641728634, '4.0%'),
#   Text(0.46160823983021715, 0.38329862107872065, '4.0%'),
#   Text(0.3520372054892863, 0.4858701533859576, '4.0%'),
#   Text(0.22043770625420803, 0.5580387241593395, '4.0%'),
#   Text(0.07504448238477379, 0.5952884390474934, '4.0%')])

# %%
###  [참고] 웹에서 제공하는 데이타를 다운로드하기 

# import urllib.request as req

# local = './data/president/presidents.xlsx'  # data폴더 밑에 president 폴더가 있어야 한다
# url = 'http://qrc.depaul.edu/excel_files/presidents.xlsx'
# req.urlretrieve(url,local)
# print('다운로드 완료')

# %% [markdown]
# ####  데이타 정보 확인하기
#
# - print(type(df))  # 데이타 타입
# - print(df.shape) # 행과 열의 수
# - print(df.columns) # 컬럼명 확인
# - print(df.dtypes) # 각각의 컬럼 데이타타입
# - print(df.info()) # df.dtypes 비슷
# - print(df.info) # 전체적인 내용을???
# - print(df.head())
# - print(df.tail())

# %% [markdown]
# ### * 인사이트를 도출하여 정보를 추출하고 시각화
